# %% [markdown]
# # Model Training and Evaluation
#
# This notebook prepares the environment by installing necessary libraries, importing modules, mounting Google Drive, and setting up directories. It then loads and cleans the dataset, applying a text cleaning function and setting up label mappings. To address class imbalance, the training data is oversampled. The datasets are then tokenized using the DistilBERT tokenizer. A function for computing evaluation metrics such as accuracy, precision, recall, and F1-score is defined. The DistilBERT model for sequence classification is loaded, and training parameters are defined. The model is then initialized and trained using the Hugging Face Trainer on the prepared datasets. After training, the fine-tuned model and tokenizer are saved to Google Drive. Finally, the trained model is evaluated on the test set, a confusion matrix is generated, and training and validation metrics are visualized.

# %%
# =========================
# Step 1 – Install necessary packages (run once)
# =========================
# !pip install transformers datasets scikit-learn wandb imblearn


# =========================
# Step 2 – Imports
# =========================
from transformers import AutoTokenizer, DistilBertForSequenceClassification, TrainingArguments, Trainer
from datasets import load_dataset, Dataset
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, ConfusionMatrixDisplay
from imblearn.over_sampling import RandomOverSampler
import pandas as pd
import torch
import numpy as np
import matplotlib.pyplot as plt
import re
import string
import wandb
import os


# =========================
# Step 3 – Log in to Weights & Biases (run once)
# =========================
wandb.login()


# =========================
# Step 4 – Mount Google Drive (if using Colab)
# =========================
from google.colab import drive
drive.mount('/content/drive')
drive_path = '/content/drive/MyDrive/datasets/'
os.makedirs(drive_path, exist_ok=True)


# =========================
# Step 5 – Load and clean dataset
# =========================
dataset = load_dataset("cnamuangtoun/resume-job-description-fit")

def clean_text(text):
    text = re.sub(r'\S+@\S+', '', text)
    text = re.sub(r'\b\d{10,}\b', '', text)
    text = re.sub(r'\d+\s+\w+\s+(Street|St|Avenue|Ave|Road|Rd|Boulevard|Blvd|Lane|Ln|Drive|Dr)\b', '', text, flags=re.IGNORECASE)
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = text.lower()
    text = re.sub(r'\s+', ' ', text).strip()
    return text

label_to_id = {'No Fit': 0, 'Potential Fit': 1, 'Good Fit': 2}
id2label = {v: k for k, v in label_to_id.items()}

def preprocess_batch(batch):
    batch['resume_text'] = [clean_text(t) for t in batch['resume_text']]
    batch['job_description_text'] = [clean_text(t) for t in batch['job_description_text']]
    batch['label_id'] = [label_to_id[l] for l in batch['label']]
    return batch

dataset = dataset.map(preprocess_batch, batched=True)


# =========================
# Step 6 – Oversample training data before tokenization
# =========================
df_train = pd.DataFrame(dataset['train'])
ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(df_train[['resume_text', 'job_description_text']], df_train['label_id'])
df_train_resampled = pd.DataFrame(X_resampled)
df_train_resampled['label_id'] = y_resampled
print("✅ Resampled class distribution:")
print(df_train_resampled['label_id'].value_counts().sort_index().rename(index=id2label))
df_train_resampled.to_csv(drive_path + "resampled_train.csv", index=False)

# Convert to Hugging Face dataset
resampled_train_dataset = Dataset.from_pandas(df_train_resampled)


# =========================
# Step 7 – Tokenization
# =========================
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")

def tokenize_function(example):
    return tokenizer(
        example["resume_text"],
        example["job_description_text"],
        truncation=True,
        padding="max_length",
        max_length=512,
    )

# Tokenize datasets
tokenized_train = resampled_train_dataset.map(tokenize_function, batched=True)
tokenized_test = dataset['test'].map(tokenize_function, batched=True)

# Remove original text columns
tokenized_train = tokenized_train.remove_columns(["resume_text", "job_description_text"])
tokenized_test = tokenized_test.remove_columns(["resume_text", "job_description_text"])

# Rename columns to 'label' ensuring no conflicts
tokenized_train = tokenized_train.rename_column("label_id", "label")

# Fix for test set: remove string 'label' if exists before renaming
if "label" in tokenized_test.column_names and tokenized_test.features["label"].dtype == "string":
    tokenized_test = tokenized_test.remove_columns("label")

tokenized_test = tokenized_test.rename_column("label_id", "label")


# =========================
# Step 8 – Define metrics function
# =========================
def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='weighted')
    acc = accuracy_score(labels, preds)

    p_class, r_class, f_class, _ = precision_recall_fscore_support(labels, preds, average=None, labels=[0, 1, 2])
    metrics = {'accuracy': acc, 'f1': f1, 'precision': precision, 'recall': recall}
    for i, label in id2label.items():
        key = label.replace(" ", "_").lower()
        metrics[f'precision_{key}'] = p_class[i]
        metrics[f'recall_{key}'] = r_class[i]
        metrics[f'f1_{key}'] = f_class[i]

    step = trainer.state.global_step if hasattr(trainer.state, "global_step") else 0
    print(f"\n🔎 Step {step}")
    for k, v in metrics.items():
        print(f"{k}: {v:.4f}")
    return metrics


# =========================
# Step 9 – Load model
# =========================
model = DistilBertForSequenceClassification.from_pretrained("distilbert-base-uncased", num_labels=3)


# =========================
# Step 10 – Training arguments
# =========================
training_args = TrainingArguments(
    output_dir="./results_distilbert",
    num_train_epochs=3,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    logging_steps=50,
    eval_strategy="steps",
    eval_steps=50,
    do_eval=True,
    seed=42,
    disable_tqdm=False,
    no_cuda=not torch.cuda.is_available(),
    report_to="wandb",
    run_name="resume-fit-distilbert-final"
)


# =========================
# Step 11 – Initialize Trainer
# =========================
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_test,
    compute_metrics=compute_metrics,
)


# =========================
# Step 12 – Train the model
# =========================
trainer.train()


# =========================
# Step 13 – Save model and tokenizer
# =========================
save_path = "/content/drive/MyDrive/datasets/fine_tuned_distilbert_model"
model.save_pretrained(save_path)
tokenizer.save_pretrained(save_path)
print("✅ Model and tokenizer saved to Google Drive!")
print(f"Saved to: {save_path}")


# =========================
# Step 14 – Evaluation predictions
# =========================
eval_preds = trainer.predict(tokenized_test)


# =========================
# Step 15 – Confusion matrix
# =========================
cm = confusion_matrix(eval_preds.label_ids, eval_preds.predictions.argmax(-1), labels=[0, 1, 2])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["No Fit", "Potential Fit", "Good Fit"])
disp.plot(cmap="Blues")
plt.title("Confusion Matrix")
plt.show()


# =========================
# Step 16 – Plot training & validation metrics
# =========================
history = trainer.state.log_history
train_loss = [entry['loss'] for entry in history if 'loss' in entry]
eval_logs = [entry for entry in history if 'eval_loss' in entry]
eval_loss = [entry['eval_loss'] for entry in eval_logs]
eval_accuracy = [entry['eval_accuracy'] for entry in eval_logs]
eval_f1 = [entry['eval_f1'] for entry in eval_logs]
steps_train = [entry['step'] for entry in history if 'loss' in entry]
steps_eval = [entry['step'] for entry in eval_logs]

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(steps_train, train_loss, label='Training Loss')
plt.plot(steps_eval, eval_loss, label='Validation Loss')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(steps_eval, eval_accuracy, label='Validation Accuracy')
plt.plot(steps_eval, eval_f1, label='Validation F1')
plt.xlabel('Steps')
plt.ylabel('Score')
plt.title('Validation Accuracy and F1')
plt.legend()
plt.tight_layout()
plt.show()


# =========================
# Step 17 – Plot per-class F1
# =========================
plt.figure(figsize=(10, 6))
for i, label in id2label.items():
    key = label.replace(" ", "_").lower()
    f1_scores = [entry.get(f'eval_f1_{key}', None) for entry in eval_logs]
    plt.plot(steps_eval, f1_scores, label=f'F1: {label}')

plt.xlabel('Steps')
plt.ylabel('F1 Score')
plt.title('Per-Class Validation F1 Over Time')
plt.legend()
plt.show()
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.54.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (4.0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (0.21.0)
# Requirement already satisfied: imblearn in /usr/local/lib/python3.11/dist-packages (0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.34.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb) (8.2.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb) (4.3.8)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (5.29.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.11.7)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb) (2.34.1)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.11/dist-packages (from wandb) (4.14.1)
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.11/dist-packages (from imblearn) (0.13.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.12.15)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.7.14)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn->imblearn) (0.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Map:   0%|          | 0/6241 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1759 [00:00<?, ? examples/s]
# ✅ Resampled class distribution:
# label_id
# No Fit           3143
# Potential Fit    3143
# Good Fit         3143
# Name: count, dtype: int64
# Map:   0%|          | 0/9429 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1759 [00:00<?, ? examples/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='3537' max='3537' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3537/3537 52:37, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Precision No Fit</th>
#       <th>Recall No Fit</th>
#       <th>F1 No Fit</th>
#       <th>Precision Potential Fit</th>
#       <th>Recall Potential Fit</th>
#       <th>F1 Potential Fit</th>
#       <th>Precision Good Fit</th>
#       <th>Recall Good Fit</th>
#       <th>F1 Good Fit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.102700</td>
#       <td>1.096364</td>
#       <td>0.472428</td>
#       <td>0.336158</td>
#       <td>0.379265</td>
#       <td>0.472428</td>
#       <td>0.487613</td>
#       <td>0.941657</td>
#       <td>0.642516</td>
#       <td>0.333333</td>
#       <td>0.006757</td>
#       <td>0.013245</td>
#       <td>0.221053</td>
#       <td>0.045852</td>
#       <td>0.075949</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.097100</td>
#       <td>1.120636</td>
#       <td>0.265492</td>
#       <td>0.118048</td>
#       <td>0.320560</td>
#       <td>0.265492</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>0.020270</td>
#       <td>0.039735</td>
#       <td>0.261714</td>
#       <td>1.000000</td>
#       <td>0.414855</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.091100</td>
#       <td>1.098811</td>
#       <td>0.304719</td>
#       <td>0.304234</td>
#       <td>0.386411</td>
#       <td>0.304719</td>
#       <td>0.534884</td>
#       <td>0.241540</td>
#       <td>0.332797</td>
#       <td>0.233098</td>
#       <td>0.520270</td>
#       <td>0.321951</td>
#       <td>0.257218</td>
#       <td>0.213974</td>
#       <td>0.233611</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.056700</td>
#       <td>1.163239</td>
#       <td>0.351336</td>
#       <td>0.289868</td>
#       <td>0.333691</td>
#       <td>0.351336</td>
#       <td>0.529933</td>
#       <td>0.278880</td>
#       <td>0.365443</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.289977</td>
#       <td>0.827511</td>
#       <td>0.429462</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.040700</td>
#       <td>1.144427</td>
#       <td>0.286526</td>
#       <td>0.223482</td>
#       <td>0.403965</td>
#       <td>0.286526</td>
#       <td>0.549180</td>
#       <td>0.078180</td>
#       <td>0.136874</td>
#       <td>0.267521</td>
#       <td>0.799550</td>
#       <td>0.400903</td>
#       <td>0.264516</td>
#       <td>0.179039</td>
#       <td>0.213542</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.957800</td>
#       <td>1.178419</td>
#       <td>0.361569</td>
#       <td>0.356728</td>
#       <td>0.425539</td>
#       <td>0.361569</td>
#       <td>0.548969</td>
#       <td>0.248541</td>
#       <td>0.342169</td>
#       <td>0.306122</td>
#       <td>0.405405</td>
#       <td>0.348837</td>
#       <td>0.310345</td>
#       <td>0.530568</td>
#       <td>0.391620</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.982300</td>
#       <td>1.179335</td>
#       <td>0.434906</td>
#       <td>0.411886</td>
#       <td>0.409406</td>
#       <td>0.434906</td>
#       <td>0.530374</td>
#       <td>0.529755</td>
#       <td>0.530064</td>
#       <td>0.198068</td>
#       <td>0.092342</td>
#       <td>0.125960</td>
#       <td>0.387931</td>
#       <td>0.589520</td>
#       <td>0.467938</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.914300</td>
#       <td>1.181332</td>
#       <td>0.407618</td>
#       <td>0.403314</td>
#       <td>0.401969</td>
#       <td>0.407618</td>
#       <td>0.552257</td>
#       <td>0.542590</td>
#       <td>0.547381</td>
#       <td>0.182073</td>
#       <td>0.146396</td>
#       <td>0.162297</td>
#       <td>0.333929</td>
#       <td>0.408297</td>
#       <td>0.367387</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.918700</td>
#       <td>1.146996</td>
#       <td>0.388857</td>
#       <td>0.391890</td>
#       <td>0.416460</td>
#       <td>0.388857</td>
#       <td>0.499162</td>
#       <td>0.347725</td>
#       <td>0.409904</td>
#       <td>0.304606</td>
#       <td>0.461712</td>
#       <td>0.367055</td>
#       <td>0.370143</td>
#       <td>0.395197</td>
#       <td>0.382260</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.948900</td>
#       <td>1.227617</td>
#       <td>0.312109</td>
#       <td>0.249145</td>
#       <td>0.459428</td>
#       <td>0.312109</td>
#       <td>0.604167</td>
#       <td>0.067678</td>
#       <td>0.121721</td>
#       <td>0.273224</td>
#       <td>0.788288</td>
#       <td>0.405797</td>
#       <td>0.369110</td>
#       <td>0.307860</td>
#       <td>0.335714</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.906400</td>
#       <td>1.158468</td>
#       <td>0.414440</td>
#       <td>0.389912</td>
#       <td>0.393557</td>
#       <td>0.414440</td>
#       <td>0.515152</td>
#       <td>0.535589</td>
#       <td>0.525172</td>
#       <td>0.224359</td>
#       <td>0.078829</td>
#       <td>0.116667</td>
#       <td>0.330056</td>
#       <td>0.513100</td>
#       <td>0.401709</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.893600</td>
#       <td>1.097169</td>
#       <td>0.440591</td>
#       <td>0.375180</td>
#       <td>0.326926</td>
#       <td>0.440591</td>
#       <td>0.490709</td>
#       <td>0.677946</td>
#       <td>0.569329</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.337391</td>
#       <td>0.423581</td>
#       <td>0.375605</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.840700</td>
#       <td>1.163947</td>
#       <td>0.378624</td>
#       <td>0.356319</td>
#       <td>0.448025</td>
#       <td>0.378624</td>
#       <td>0.559322</td>
#       <td>0.192532</td>
#       <td>0.286458</td>
#       <td>0.343032</td>
#       <td>0.504505</td>
#       <td>0.408387</td>
#       <td>0.341554</td>
#       <td>0.604803</td>
#       <td>0.436564</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.878400</td>
#       <td>1.208431</td>
#       <td>0.442297</td>
#       <td>0.430755</td>
#       <td>0.434542</td>
#       <td>0.442297</td>
#       <td>0.545455</td>
#       <td>0.644107</td>
#       <td>0.590690</td>
#       <td>0.234177</td>
#       <td>0.250000</td>
#       <td>0.241830</td>
#       <td>0.421245</td>
#       <td>0.251092</td>
#       <td>0.314637</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.804500</td>
#       <td>1.577746</td>
#       <td>0.310404</td>
#       <td>0.247815</td>
#       <td>0.372296</td>
#       <td>0.310404</td>
#       <td>0.466418</td>
#       <td>0.145858</td>
#       <td>0.222222</td>
#       <td>0.282258</td>
#       <td>0.867117</td>
#       <td>0.425885</td>
#       <td>0.283465</td>
#       <td>0.078603</td>
#       <td>0.123077</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.893200</td>
#       <td>1.074377</td>
#       <td>0.436612</td>
#       <td>0.432900</td>
#       <td>0.430446</td>
#       <td>0.436612</td>
#       <td>0.515184</td>
#       <td>0.554259</td>
#       <td>0.534008</td>
#       <td>0.345865</td>
#       <td>0.310811</td>
#       <td>0.327402</td>
#       <td>0.353881</td>
#       <td>0.338428</td>
#       <td>0.345982</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.827000</td>
#       <td>1.285129</td>
#       <td>0.490051</td>
#       <td>0.364196</td>
#       <td>0.478914</td>
#       <td>0.490051</td>
#       <td>0.493939</td>
#       <td>0.950992</td>
#       <td>0.650179</td>
#       <td>0.558824</td>
#       <td>0.042793</td>
#       <td>0.079498</td>
#       <td>0.373333</td>
#       <td>0.061135</td>
#       <td>0.105066</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.863700</td>
#       <td>1.456515</td>
#       <td>0.313815</td>
#       <td>0.278999</td>
#       <td>0.407101</td>
#       <td>0.313815</td>
#       <td>0.481100</td>
#       <td>0.163361</td>
#       <td>0.243902</td>
#       <td>0.261719</td>
#       <td>0.754505</td>
#       <td>0.388631</td>
#       <td>0.409574</td>
#       <td>0.168122</td>
#       <td>0.238390</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.836900</td>
#       <td>1.322151</td>
#       <td>0.428084<
# 🔎 Step 50
# accuracy: 0.4724
# f1: 0.3362
# precision: 0.3793
# recall: 0.4724
# precision_no_fit: 0.4876
# recall_no_fit: 0.9417
# f1_no_fit: 0.6425
# precision_potential_fit: 0.3333
# recall_potential_fit: 0.0068
# f1_potential_fit: 0.0132
# precision_good_fit: 0.2211
# recall_good_fit: 0.0459
# f1_good_fit: 0.0759
#
# 🔎 Step 100
# accuracy: 0.2655
# f1: 0.1180
# precision: 0.3206
# recall: 0.2655
# precision_no_fit: 0.0000
# recall_no_fit: 0.0000
# f1_no_fit: 0.0000
# precision_potential_fit: 1.0000
# recall_potential_fit: 0.0203
# f1_potential_fit: 0.0397
# precision_good_fit: 0.2617
# recall_good_fit: 1.0000
# f1_good_fit: 0.4149
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 🔎 Step 150
# accuracy: 0.3047
# f1: 0.3042
# precision: 0.3864
# recall: 0.3047
# precision_no_fit: 0.5349
# recall_no_fit: 0.2415
# f1_no_fit: 0.3328
# precision_potential_fit: 0.2331
# recall_potential_fit: 0.5203
# f1_potential_fit: 0.3220
# precision_good_fit: 0.2572
# recall_good_fit: 0.2140
# f1_good_fit: 0.2336
#
# 🔎 Step 200
# accuracy: 0.3513
# f1: 0.2899
# precision: 0.3337
# recall: 0.3513
# precision_no_fit: 0.5299
# recall_no_fit: 0.2789
# f1_no_fit: 0.3654
# precision_potential_fit: 0.0000
# recall_potential_fit: 0.0000
# f1_potential_fit: 0.0000
# precision_good_fit: 0.2900
# recall_good_fit: 0.8275
# f1_good_fit: 0.4295
#
# 🔎 Step 250
# accuracy: 0.2865
# f1: 0.2235
# precision: 0.4040
# recall: 0.2865
# precision_no_fit: 0.5492
# recall_no_fit: 0.0782
# f1_no_fit: 0.1369
# precision_potential_fit: 0.2675
# recall_potential_fit: 0.7995
# f1_potential_fit: 0.4009
# precision_good_fit: 0.2645
# recall_good_fit: 0.1790
# f1_good_fit: 0.2135
#
# 🔎 Step 300
# accuracy: 0.3616
# f1: 0.3567
# precision: 0.4255
# recall: 0.3616
# precision_no_fit: 0.5490
# recall_no_fit: 0.2485
# f1_no_fit: 0.3422
# precision_potential_fit: 0.3061
# recall_potential_fit: 0.4054
# f1_potential_fit: 0.3488
# precision_good_fit: 0.3103
# recall_good_fit: 0.5306
# f1_good_fit: 0.3916
#
# 🔎 Step 350
# accuracy: 0.4349
# f1: 0.4119
# precision: 0.4094
# recall: 0.4349
# precision_no_fit: 0.5304
# recall_no_fit: 0.5298
# f1_no_fit: 0.5301
# precision_potential_fit: 0.1981
# recall_potential_fit: 0.0923
# f1_potential_fit: 0.1260
# precision_good_fit: 0.3879
# recall_good_fit: 0.5895
# f1_good_fit: 0.4679
#
# 🔎 Step 400
# accuracy: 0.4076
# f1: 0.4033
# precision: 0.4020
# recall: 0.4076
# precision_no_fit: 0.5523
# recall_no_fit: 0.5426
# f1_no_fit: 0.5474
# precision_potential_fit: 0.1821
# recall_potential_fit: 0.1464
# f1_potential_fit: 0.1623
# precision_good_fit: 0.3339
# recall_good_fit: 0.4083
# f1_good_fit: 0.3674
#
# 🔎 Step 450
# accuracy: 0.3889
# f1: 0.3919
# precision: 0.4165
# recall: 0.3889
# precision_no_fit: 0.4992
# recall_no_fit: 0.3477
# f1_no_fit: 0.4099
# precision_potential_fit: 0.3046
# recall_potential_fit: 0.4617
# f1_potential_fit: 0.3671
# precision_good_fit: 0.3701
# recall_good_fit: 0.3952
# f1_good_fit: 0.3823
#
# 🔎 Step 500
# accuracy: 0.3121
# f1: 0.2491
# precision: 0.4594
# recall: 0.3121
# precision_no_fit: 0.6042
# recall_no_fit: 0.0677
# f1_no_fit: 0.1217
# precision_potential_fit: 0.2732
# recall_potential_fit: 0.7883
# f1_potential_fit: 0.4058
# precision_good_fit: 0.3691
# recall_good_fit: 0.3079
# f1_good_fit: 0.3357
#
# 🔎 Step 550
# accuracy: 0.4144
# f1: 0.3899
# precision: 0.3936
# recall: 0.4144
# precision_no_fit: 0.5152
# recall_no_fit: 0.5356
# f1_no_fit: 0.5252
# precision_potential_fit: 0.2244
# recall_potential_fit: 0.0788
# f1_potential_fit: 0.1167
# precision_good_fit: 0.3301
# recall_good_fit: 0.5131
# f1_good_fit: 0.4017
#
# 🔎 Step 600
# accuracy: 0.4406
# f1: 0.3752
# precision: 0.3269
# recall: 0.4406
# precision_no_fit: 0.4907
# recall_no_fit: 0.6779
# f1_no_fit: 0.5693
# precision_potential_fit: 0.0000
# recall_potential_fit: 0.0000
# f1_potential_fit: 0.0000
# precision_good_fit: 0.3374
# recall_good_fit: 0.4236
# f1_good_fit: 0.3756
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 🔎 Step 650
# accuracy: 0.3786
# f1: 0.3563
# precision: 0.4480
# recall: 0.3786
# precision_no_fit: 0.5593
# recall_no_fit: 0.1925
# f1_no_fit: 0.2865
# precision_potential_fit: 0.3430
# recall_potential_fit: 0.5045
# f1_potential_fit: 0.4084
# precision_good_fit: 0.3416
# recall_good_fit: 0.6048
# f1_good_fit: 0.4366
#
# 🔎 Step 700
# accuracy: 0.4423
# f1: 0.4308
# precision: 0.4345
# recall: 0.4423
# precision_no_fit: 0.5455
# recall_no_fit: 0.6441
# f1_no_fit: 0.5907
# precision_potential_fit: 0.2342
# recall_potential_fit: 0.2500
# f1_potential_fit: 0.2418
# precision_good_fit: 0.4212
# recall_good_fit: 0.2511
# f1_good_fit: 0.3146
#
# 🔎 Step 750
# accuracy: 0.3104
# f1: 0.2478
# precision: 0.3723
# recall: 0.3104
# precision_no_fit: 0.4664
# recall_no_fit: 0.1459
# f1_no_fit: 0.2222
# precision_potential_fit: 0.2823
# recall_potential_fit: 0.8671
# f1_potential_fit: 0.4259
# precision_good_fit: 0.2835
# recall_good_fit: 0.0786
# f1_good_fit: 0.1231
#
# 🔎 Step 800
# accuracy: 0.4366
# f1: 0.4329
# precision: 0.4304
# recall: 0.4366
# precision_no_fit: 0.5152
# recall_no_fit: 0.5543
# f1_no_fit: 0.5340
# precision_potential_fit: 0.3459
# recall_potential_fit: 0.3108
# f1_potential_fit: 0.3274
# precision_good_fit: 0.3539
# recall_good_fit: 0.3384
# f1_good_fit: 0.3460
#
# 🔎 Step 850
# accuracy: 0.4901
# f1: 0.3642
# precision: 0.4789
# recall: 0.4901
# precision_no_fit: 0.4939
# recall_no_fit: 0.9510
# f1_no_fit: 0.6502
# precision_potential_fit: 0.5588
# recall_potential_fit: 0.0428
# f1_potential_fit: 0.0795
# precision_good_fit: 0.3733
# recall_good_fit: 0.0611
# f1_good_fit: 0.1051
#
# 🔎 Step 900
# accuracy: 0.3138
# f1: 0.2790
# precision: 0.4071
# recall: 0.3138
# precision_no_fit: 0.4811
# recall_no_fit: 0.1634
# f1_no_fit: 0.2439
# precision_potential_fit: 0.2617
# recall_potential_fit: 0.7545
# f1_potential_fit: 0.3886
# precision_good_fit: 0.4096
# recall_good_fit: 0.1681
# f1_good_fit: 0.2384
#
# 🔎 Step 950
# accuracy: 0.4281
# f1: 0.4151
# precision: 0.4679
# recall: 0.4281
# precision_no_fit: 0.5184
# recall_no_fit: 0.4924
# f1_no_fit: 0.5051
# precision_potential_fit: 0.3195
# recall_potential_fit: 0.5743
# f1_potential_fit: 0.4106
# precision_good_fit: 0.5170
# recall_good_fit: 0.1659
# f1_good_fit: 0.2512
#
# 🔎 Step 1000
# accuracy: 0.4309
# f1: 0.4196
# precision: 0.4549
# recall: 0.4309
# precision_no_fit: 0.5522
# recall_no_fit: 0.4749
# f1_no_fit: 0.5107
# precision_potential_fit: 0.3936
# recall_potential_fit: 0.1667
# f1_potential_fit: 0.2342
# precision_good_fit: 0.3321
# recall_good_fit: 0.6048
# f1_good_fit: 0.4288
#
# 🔎 Step 1050
# accuracy: 0.4451
# f1: 0.4305
# precision: 0.4264
# recall: 0.4451
# precision_no_fit: 0.5144
# recall_no_fit: 0.6266
# f1_no_fit: 0.5650
# precision_potential_fit: 0.3528
# recall_potential_fit: 0.3131
# f1_potential_fit: 0.3317
# precision_good_fit: 0.3333
# recall_good_fit: 0.2336
# f1_good_fit: 0.2747
#
# 🔎 Step 1100
# accuracy: 0.4480
# f1: 0.4398
# precision: 0.4565
# recall: 0.4480
# precision_no_fit: 0.5225
# recall_no_fit: 0.5963
# f1_no_fit: 0.5569
# precision_potential_fit: 0.3000
# recall_potential_fit: 0.3716
# f1_potential_fit: 0.3320
# precision_good_fit: 0.4848
# recall_good_fit: 0.2445
# f1_good_fit: 0.3251
#
# 🔎 Step 1150
# accuracy: 0.4332
# f1: 0.4255
# precision: 0.4306
# recall: 0.4332
# precision_no_fit: 0.5037
# recall_no_fit: 0.5519
# f1_no_fit: 0.5267
# precision_potential_fit: 0.3352
# recall_potential_fit: 0.4099
# f1_potential_fit: 0.3688
# precision_good_fit: 0.3863
# recall_good_fit: 0.2336
# f1_good_fit: 0.2912
#
# 🔎 Step 1200
# accuracy: 0.3837
# f1: 0.3621
# precision: 0.4340
# recall: 0.3837
# precision_no_fit: 0.5444
# recall_no_fit: 0.4294
# f1_no_fit: 0.4801
# precision_potential_fit: 0.2746
# recall_potential_fit: 0.6149
# f1_potential_fit: 0.3797
# precision_good_fit: 0.3820
# recall_good_fit: 0.0742
# f1_good_fit: 0.1243
#
# 🔎 Step 1250
# accuracy: 0.3701
# f1: 0.3678
# precision: 0.4154
# recall: 0.3701
# precision_no_fit: 0.5332
# recall_no_fit: 0.3559
# f1_no_fit: 0.4269
# precision_potential_fit: 0.2810
# recall_potential_fit: 0.5721
# f1_potential_fit: 0.3769
# precision_good_fit: 0.3251
# recall_good_fit: 0.2009
# f1_good_fit: 0.2483
#
# 🔎 Step 1300
# accuracy: 0.3161
# f1: 0.2720
# precision: 0.4762
# recall: 0.3161
# precision_no_fit: 0.6322
# recall_no_fit: 0.1284
# f1_no_fit: 0.2134
# precision_potential_fit: 0.2627
# recall_potential_fit: 0.8018
# f1_potential_fit: 0.3958
# precision_good_fit: 0.3913
# recall_good_fit: 0.1965
# f1_good_fit: 0.2616
#
# 🔎 Step 1350
# accuracy: 0.4332
# f1: 0.4181
# precision: 0.4314
# recall: 0.4332
# precision_no_fit: 0.5163
# recall_no_fit: 0.6301
# f1_no_fit: 0.5675
# precision_potential_fit: 0.2545
# recall_potential_fit: 0.2860
# f1_potential_fit: 0.2694
# precision_good_fit: 0.4439
# recall_good_fit: 0.2074
# f1_good_fit: 0.2827
#
# 🔎 Step 1400
# accuracy: 0.3940
# f1: 0.3557
# precision: 0.3808
# recall: 0.3940
# precision_no_fit: 0.5489
# recall_no_fit: 0.5309
# f1_no_fit: 0.5397
# precision_potential_fit: 0.2580
# recall_potential_fit: 0.5248
# f1_potential_fit: 0.3460
# precision_good_fit: 0.1852
# recall_good_fit: 0.0109
# f1_good_fit: 0.0206
#
# 🔎 Step 1450
# accuracy: 0.3980
# f1: 0.3936
# precision: 0.4485
# recall: 0.3980
# precision_no_fit: 0.5369
# recall_no_fit: 0.4749
# f1_no_fit: 0.5040
# precision_potential_fit: 0.2607
# recall_potential_fit: 0.4955
# f1_potential_fit: 0.3416
# precision_good_fit: 0.4650
# recall_good_fit: 0.1594
# f1_good_fit: 0.2374
#
# 🔎 Step 1500
# accuracy: 0.4264
# f1: 0.4137
# precision: 0.4193
# recall: 0.4264
# precision_no_fit: 0.4975
# recall_no_fit: 0.5893
# f1_no_fit: 0.5395
# precision_potential_fit: 0.2998
# recall_potential_fit: 0.3356
# f1_potential_fit: 0.3167
# precision_good_fit: 0.3887
# recall_good_fit: 0.2096
# f1_good_fit: 0.2723
#
# 🔎 Step 1550
# accuracy: 0.3980
# f1: 0.3871
# precision: 0.4081
# recall: 0.3980
# precision_no_fit: 0.5123
# recall_no_fit: 0.4842
# f1_no_fit: 0.4979
# precision_potential_fit: 0.2941
# recall_potential_fit: 0.4955
# f1_potential_fit: 0.3691
# precision_good_fit: 0.3234
# recall_good_fit: 0.1419
# f1_good_fit: 0.1973
#
# 🔎 Step 1600
# accuracy: 0.4042
# f1: 0.4096
# precision: 0.4337
# recall: 0.4042
# precision_no_fit: 0.5741
# recall_no_fit: 0.4702
# f1_no_fit: 0.5170
# precision_potential_fit: 0.2764
# recall_potential_fit: 0.4482
# f1_potential_fit: 0.3419
# precision_good_fit: 0.3234
# recall_good_fit: 0.2380
# f1_good_fit: 0.2742
#
# 🔎 Step 1650
# accuracy: 0.4093
# f1: 0.4099
# precision: 0.4336
# recall: 0.4093
# precision_no_fit: 0.5712
# recall_no_fit: 0.4866
# f1_no_fit: 0.5255
# precision_potential_fit: 0.2846
# recall_potential_fit: 0.4775
# f1_potential_fit: 0.3566
# precision_good_fit: 0.3204
# recall_good_fit: 0.1987
# f1_good_fit: 0.2453
#
# 🔎 Step 1700
# accuracy: 0.4423
# f1: 0.4346
# precision: 0.4359
# recall: 0.4423
# precision_no_fit: 0.5668
# recall_no_fit: 0.6184
# f1_no_fit: 0.5915
# precision_potential_fit: 0.2751
# recall_potential_fit: 0.3266
# f1_potential_fit: 0.2987
# precision_good_fit: 0.3468
# recall_good_fit: 0.2249
# f1_good_fit: 0.2728
#
# 🔎 Step 1750
# accuracy: 0.3877
# f1: 0.3821
# precision: 0.4337
# recall: 0.3877
# precision_no_fit: 0.5873
# recall_no_fit: 0.4201
# f1_no_fit: 0.4898
# precision_potential_fit: 0.2772
# recall_potential_fit: 0.5856
# f1_potential_fit: 0.3763
# precision_good_fit: 0.2981
# recall_good_fit: 0.1354
# f1_good_fit: 0.1862
#
# 🔎 Step 1800
# accuracy: 0.4338
# f1: 0.4386
# precision: 0.4511
# recall: 0.4338
# precision_no_fit: 0.5785
# recall_no_fit: 0.5076
# f1_no_fit: 0.5407
# precision_potential_fit: 0.3103
# recall_potential_fit: 0.4257
# f1_potential_fit: 0.3590
# precision_good_fit: 0.3492
# recall_good_fit: 0.3035
# f1_good_fit: 0.3248
#
# 🔎 Step 1850
# accuracy: 0.4014
# f1: 0.4003
# precision: 0.4617
# recall: 0.4014
# precision_no_fit: 0.5879
# recall_no_fit: 0.3862
# f1_no_fit: 0.4662
# precision_potential_fit: 0.2929
# recall_potential_fit: 0.6194
# f1_potential_fit: 0.3977
# precision_good_fit: 0.3891
# recall_good_fit: 0.2183
# f1_good_fit: 0.2797
#
# 🔎 Step 1900
# accuracy: 0.4571
# f1: 0.4328
# precision: 0.4364
# recall: 0.4571
# precision_no_fit: 0.5604
# recall_no_fit: 0.6873
# f1_no_fit: 0.6174
# precision_potential_fit: 0.2857
# recall_potential_fit: 0.3288
# f1_potential_fit: 0.3058
# precision_good_fit: 0.3503
# recall_good_fit: 0.1507
# f1_good_fit: 0.2107
#
# 🔎 Step 1950
# accuracy: 0.4116
# f1: 0.4176
# precision: 0.4505
# recall: 0.4116
# precision_no_fit: 0.5833
# recall_no_fit: 0.4574
# f1_no_fit: 0.5128
# precision_potential_fit: 0.2802
# recall_potential_fit: 0.4865
# f1_potential_fit: 0.3556
# precision_good_fit: 0.3671
# recall_good_fit: 0.2533
# f1_good_fit: 0.2997
#
# 🔎 Step 2000
# accuracy: 0.4127
# f1: 0.3823
# precision: 0.3900
# recall: 0.4127
# precision_no_fit: 0.5530
# recall_no_fit: 0.6091
# f1_no_fit: 0.5797
# precision_potential_fit: 0.2553
# recall_potential_fit: 0.4099
# f1_potential_fit: 0.3146
# precision_good_fit: 0.2157
# recall_good_fit: 0.0480
# f1_good_fit: 0.0786
#
# 🔎 Step 2050
# accuracy: 0.3962
# f1: 0.3916
# precision: 0.4182
# recall: 0.3962
# precision_no_fit: 0.5409
# recall_no_fit: 0.4702
# f1_no_fit: 0.5031
# precision_potential_fit: 0.2806
# recall_potential_fit: 0.4955
# f1_potential_fit: 0.3583
# precision_good_fit: 0.3217
# recall_good_fit: 0.1616
# f1_good_fit: 0.2151
#
# 🔎 Step 2100
# accuracy: 0.4167
# f1: 0.4228
# precision: 0.4482
# recall: 0.4167
# precision_no_fit: 0.5864
# recall_no_fit: 0.4912
# f1_no_fit: 0.5346
# precision_potential_fit: 0.2732
# recall_potential_fit: 0.4437
# f1_potential_fit: 0.3382
# precision_good_fit: 0.3594
# recall_good_fit: 0.2511
# f1_good_fit: 0.2956
#
# 🔎 Step 2150
# accuracy: 0.4446
# f1: 0.4401
# precision: 0.4443
# recall: 0.4446
# precision_no_fit: 0.5727
# recall_no_fit: 0.6161
# f1_no_fit: 0.5936
# precision_potential_fit: 0.2556
# recall_potential_fit: 0.3063
# f1_potential_fit: 0.2787
# precision_good_fit: 0.3869
# recall_good_fit: 0.2576
# f1_good_fit: 0.3093
#
# 🔎 Step 2200
# accuracy: 0.3678
# f1: 0.3493
# precision: 0.4642
# recall: 0.3678
# precision_no_fit: 0.6674
# recall_no_fit: 0.3396
# f1_no_fit: 0.4501
# precision_potential_fit: 0.2686
# recall_potential_fit: 0.7230
# f1_potential_fit: 0.3917
# precision_good_fit: 0.2734
# recall_good_fit: 0.0764
# f1_good_fit: 0.1195
#
# 🔎 Step 2250
# accuracy: 0.4122
# f1: 0.4227
# precision: 0.4558
# recall: 0.4122
# precision_no_fit: 0.5893
# recall_no_fit: 0.4737
# f1_no_fit: 0.5252
# precision_potential_fit: 0.2530
# recall_potential_fit: 0.4257
# f1_potential_fit: 0.3174
# precision_good_fit: 0.4025
# recall_good_fit: 0.2838
# f1_good_fit: 0.3329
#
# 🔎 Step 2300
# accuracy: 0.4161
# f1: 0.4190
# precision: 0.4701
# recall: 0.4161
# precision_no_fit: 0.6117
# recall_no_fit: 0.4761
# f1_no_fit: 0.5354
# precision_potential_fit: 0.2710
# recall_potential_fit: 0.5315
# f1_potential_fit: 0.3589
# precision_good_fit: 0.3982
# recall_good_fit: 0.1921
# f1_good_fit: 0.2592
#
# 🔎 Step 2350
# accuracy: 0.4241
# f1: 0.4368
# precision: 0.4686
# recall: 0.4241
# precision_no_fit: 0.6154
# recall_no_fit: 0.4761
# f1_no_fit: 0.5368
# precision_potential_fit: 0.2609
# recall_potential_fit: 0.4167
# f1_potential_fit: 0.3209
# precision_good_fit: 0.3953
# recall_good_fit: 0.3341
# f1_good_fit: 0.3621
#
# 🔎 Step 2400
# accuracy: 0.4161
# f1: 0.4034
# precision: 0.4267
# recall: 0.4161
# precision_no_fit: 0.5607
# recall_no_fit: 0.5823
# f1_no_fit: 0.5713
# precision_potential_fit: 0.2496
# recall_potential_fit: 0.3964
# f1_potential_fit: 0.3064
# precision_good_fit: 0.3476
# recall_good_fit: 0.1245
# f1_good_fit: 0.1833
#
# 🔎 Step 2450
# accuracy: 0.4252
# f1: 0.4287
# precision: 0.4520
# recall: 0.4252
# precision_no_fit: 0.5938
# recall_no_fit: 0.5543
# f1_no_fit: 0.5733
# precision_potential_fit: 0.2460
# recall_potential_fit: 0.3851
# f1_potential_fit: 0.3003
# precision_good_fit: 0.3864
# recall_good_fit: 0.2227
# f1_good_fit: 0.2825
#
# 🔎 Step 2500
# accuracy: 0.3837
# f1: 0.3865
# precision: 0.4509
# recall: 0.3837
# precision_no_fit: 0.6153
# recall_no_fit: 0.4236
# f1_no_fit: 0.5017
# precision_potential_fit: 0.2516
# recall_potential_fit: 0.5428
# f1_potential_fit: 0.3438
# precision_good_fit: 0.3365
# recall_good_fit: 0.1550
# f1_good_fit: 0.2123
#
# 🔎 Step 2550
# accuracy: 0.4662
# f1: 0.4424
# precision: 0.4432
# recall: 0.4662
# precision_no_fit: 0.5663
# recall_no_fit: 0.7176
# f1_no_fit: 0.6330
# precision_potential_fit: 0.2563
# recall_potential_fit: 0.2523
# f1_potential_fit: 0.2543
# precision_good_fit: 0.3941
# recall_good_fit: 0.2031
# f1_good_fit: 0.2680
#
# 🔎 Step 2600
# accuracy: 0.4451
# f1: 0.4372
# precision: 0.4516
# recall: 0.4451
# precision_no_fit: 0.5754
# recall_no_fit: 0.6278
# f1_no_fit: 0.6004
# precision_potential_fit: 0.2534
# recall_potential_fit: 0.3401
# f1_potential_fit: 0.2904
# precision_good_fit: 0.4123
# recall_good_fit: 0.2052
# f1_good_fit: 0.2741
#
# 🔎 Step 2650
# accuracy: 0.4133
# f1: 0.4184
# precision: 0.4668
# recall: 0.4133
# precision_no_fit: 0.6077
# recall_no_fit: 0.4807
# f1_no_fit: 0.5368
# precision_potential_fit: 0.2612
# recall_potential_fit: 0.5000
# f1_potential_fit: 0.3431
# precision_good_fit: 0.4026
# recall_good_fit: 0.2031
# f1_good_fit: 0.2700
#
# 🔎 Step 2700
# accuracy: 0.4798
# f1: 0.4426
# precision: 0.4454
# recall: 0.4798
# precision_no_fit: 0.5530
# recall_no_fit: 0.7666
# f1_no_fit: 0.6425
# precision_potential_fit: 0.2908
# recall_potential_fit: 0.2410
# f1_potential_fit: 0.2635
# precision_good_fit: 0.3941
# recall_good_fit: 0.1747
# f1_good_fit: 0.2421
#
# 🔎 Step 2750
# accuracy: 0.4230
# f1: 0.4303
# precision: 0.4663
# recall: 0.4230
# precision_no_fit: 0.6014
# recall_no_fit: 0.5018
# f1_no_fit: 0.5471
# precision_potential_fit: 0.2617
# recall_potential_fit: 0.4550
# f1_potential_fit: 0.3322
# precision_good_fit: 0.4118
# recall_good_fit: 0.2445
# f1_good_fit: 0.3068
#
# 🔎 Step 2800
# accuracy: 0.4076
# f1: 0.4170
# precision: 0.4619
# recall: 0.4076
# precision_no_fit: 0.6121
# recall_no_fit: 0.4714
# f1_no_fit: 0.5326
# precision_potential_fit: 0.2518
# recall_potential_fit: 0.4685
# f1_potential_fit: 0.3276
# precision_good_fit: 0.3846
# recall_good_fit: 0.2293
# f1_good_fit: 0.2873
#
# 🔎 Step 2850
# accuracy: 0.4372
# f1: 0.4302
# precision: 0.4543
# recall: 0.4372
# precision_no_fit: 0.5840
# recall_no_fit: 0.5963
# f1_no_fit: 0.5901
# precision_potential_fit: 0.2609
# recall_potential_fit: 0.4032
# f1_potential_fit: 0.3168
# precision_good_fit: 0.3990
# recall_good_fit: 0.1725
# f1_good_fit: 0.2409
#
# 🔎 Step 2900
# accuracy: 0.4133
# f1: 0.4204
# precision: 0.4600
# recall: 0.4133
# precision_no_fit: 0.6168
# recall_no_fit: 0.5053
# f1_no_fit: 0.5555
# precision_potential_fit: 0.2488
# recall_potential_fit: 0.4505
# f1_potential_fit: 0.3205
# precision_good_fit: 0.3715
# recall_good_fit: 0.2052
# f1_good_fit: 0.2644
#
# 🔎 Step 2950
# accuracy: 0.3985
# f1: 0.4103
# precision: 0.4598
# recall: 0.3985
# precision_no_fit: 0.6215
# recall_no_fit: 0.4387
# f1_no_fit: 0.5144
# precision_potential_fit: 0.2524
# recall_potential_fit: 0.4752
# f1_potential_fit: 0.3297
# precision_good_fit: 0.3585
# recall_good_fit: 0.2489
# f1_good_fit: 0.2938
#
# 🔎 Step 3000
# accuracy: 0.4360
# f1: 0.4262
# precision: 0.4422
# recall: 0.4360
# precision_no_fit: 0.5880
# recall_no_fit: 0.6196
# f1_no_fit: 0.6034
# precision_potential_fit: 0.2511
# recall_potential_fit: 0.3694
# f1_potential_fit: 0.2990
# precision_good_fit: 0.3547
# recall_good_fit: 0.1572
# f1_good_fit: 0.2179
#
# 🔎 Step 3050
# accuracy: 0.4468
# f1: 0.4278
# precision: 0.4440
# recall: 0.4468
# precision_no_fit: 0.5838
# recall_no_fit: 0.6628
# f1_no_fit: 0.6208
# precision_potential_fit: 0.2532
# recall_potential_fit: 0.3536
# f1_potential_fit: 0.2951
# precision_good_fit: 0.3675
# recall_good_fit: 0.1332
# f1_good_fit: 0.1955
#
# 🔎 Step 3100
# accuracy: 0.4559
# f1: 0.4388
# precision: 0.4462
# recall: 0.4559
# precision_no_fit: 0.5775
# recall_no_fit: 0.6779
# f1_no_fit: 0.6237
# precision_potential_fit: 0.2579
# recall_potential_fit: 0.3131
# f1_potential_fit: 0.2828
# precision_good_fit: 0.3832
# recall_good_fit: 0.1790
# f1_good_fit: 0.2440
#
# 🔎 Step 3150
# accuracy: 0.4406
# f1: 0.4405
# precision: 0.4596
# recall: 0.4406
# precision_no_fit: 0.6014
# recall_no_fit: 0.5881
# f1_no_fit: 0.5947
# precision_potential_fit: 0.2571
# recall_potential_fit: 0.3851
# f1_potential_fit: 0.3084
# precision_good_fit: 0.3906
# recall_good_fit: 0.2183
# f1_good_fit: 0.2801
#
# 🔎 Step 3200
# accuracy: 0.4537
# f1: 0.4357
# precision: 0.4478
# recall: 0.4537
# precision_no_fit: 0.5843
# recall_no_fit: 0.6709
# f1_no_fit: 0.6247
# precision_potential_fit: 0.2602
# recall_potential_fit: 0.3446
# f1_potential_fit: 0.2965
# precision_good_fit: 0.3743
# recall_good_fit: 0.1528
# f1_good_fit: 0.2171
#
# 🔎 Step 3250
# accuracy: 0.4446
# f1: 0.4402
# precision: 0.4586
# recall: 0.4446
# precision_no_fit: 0.5986
# recall_no_fit: 0.6161
# f1_no_fit: 0.6072
# precision_potential_fit: 0.2515
# recall_potential_fit: 0.3671
# f1_potential_fit: 0.2985
# precision_good_fit: 0.3974
# recall_good_fit: 0.1987
# f1_good_fit: 0.2649
#
# 🔎 Step 3300
# accuracy: 0.4537
# f1: 0.4284
# precision: 0.4365
# recall: 0.4537
# precision_no_fit: 0.5661
# recall_no_fit: 0.7048
# f1_no_fit: 0.6279
# precision_potential_fit: 0.2441
# recall_potential_fit: 0.2793
# f1_potential_fit: 0.2605
# precision_good_fit: 0.3804
# recall_good_fit: 0.1528
# f1_good_fit: 0.2181
#
# 🔎 Step 3350
# accuracy: 0.4503
# f1: 0.4398
# precision: 0.4631
# recall: 0.4503
# precision_no_fit: 0.6007
# recall_no_fit: 0.6371
# f1_no_fit: 0.6183
# precision_potential_fit: 0.2571
# recall_potential_fit: 0.3851
# f1_potential_fit: 0.3084
# precision_good_fit: 0.4054
# recall_good_fit: 0.1638
# f1_good_fit: 0.2333
#
# 🔎 Step 3400
# accuracy: 0.4360
# f1: 0.4320
# precision: 0.4629
# recall: 0.4360
# precision_no_fit: 0.6029
# recall_no_fit: 0.5881
# f1_no_fit: 0.5954
# precision_potential_fit: 0.2534
# recall_potential_fit: 0.4167
# f1_potential_fit: 0.3152
# precision_good_fit: 0.4041
# recall_good_fit: 0.1703
# f1_good_fit: 0.2396
#
# 🔎 Step 3450
# accuracy: 0.4343
# f1: 0.4311
# precision: 0.4628
# recall: 0.4343
# precision_no_fit: 0.6019
# recall_no_fit: 0.5788
# f1_no_fit: 0.5901
# precision_potential_fit: 0.2558
# recall_potential_fit: 0.4257
# f1_potential_fit: 0.3195
# precision_good_fit: 0.4031
# recall_good_fit: 0.1725
# f1_good_fit: 0.2416
#
# 🔎 Step 3500
# accuracy: 0.4491
# f1: 0.4386
# precision: 0.4574
# recall: 0.4491
# precision_no_fit: 0.5939
# recall_no_fit: 0.6383
# f1_no_fit: 0.6153
# precision_potential_fit: 0.2574
# recall_potential_fit: 0.3716
# f1_potential_fit: 0.3041
# precision_good_fit: 0.3959
# recall_good_fit: 0.1703
# f1_good_fit: 0.2382
# ✅ Model and tokenizer saved to Google Drive!
# Saved to: /content/drive/MyDrive/datasets/fine_tuned_distilbert_model
# 🔎 Step 3537
# accuracy: 0.4474
# f1: 0.4383
# precision: 0.4588
# recall: 0.4474
# precision_no_fit: 0.5980
# recall_no_fit: 0.6301
# f1_no_fit: 0.6136
# precision_potential_fit: 0.2568
# recall_potential_fit: 0.3806
# f1_potential_fit: 0.3067
# precision_good_fit: 0.3939
# recall_good_fit: 0.1703
# f1_good_fit: 0.2378

# %% [markdown]
# # Model Inference (Prediction)
# This cell loads the trained model and tokenizer from Google Drive and defines a function to predict the fit score between a resume and a job description.

# %%
# =========================
# Step 1 – Setup and Imports
# =========================
# Install if needed (skip if already installed)
# !pip install transformers

# Imports
from transformers import AutoTokenizer, DistilBertForSequenceClassification
import torch
import torch.nn.functional as F
import os


# =========================
# Step 2 – Mount Google Drive
# =========================
from google.colab import drive
drive.mount('/content/drive')


# =========================
# Step 3 – Load model and tokenizer
# =========================
model_path = "/content/drive/MyDrive/datasets/fine_tuned_distilbert_model"
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = DistilBertForSequenceClassification.from_pretrained(model_path)
model.eval()

# Move to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)


# =========================
# Step 4 – Label mapping
# =========================
id2label = {0: "No Fit", 1: "Potential Fit", 2: "Good Fit"}


# =========================
# Step 5 – Inference function
# =========================
def predict_fit(resume_text, job_desc_text):
    inputs = tokenizer(
        resume_text,
        job_desc_text,
        truncation=True,
        padding=True,
        max_length=512,
        return_tensors="pt"
    )
    inputs = {k: v.to(device) for k, v in inputs.items()}

    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits
        probs = F.softmax(logits, dim=1)
        pred_label = torch.argmax(probs, dim=1).item()
        confidence = probs[0][pred_label].item()
        good_fit_prob = probs[0][2].item()  # Probability of 'Good Fit'

    print("📄 Resume:")
    print(resume_text.strip()[:200] + "...\n")
    print("📝 Job Description:")
    print(job_desc_text.strip()[:200] + "...\n")
    print(f"🔍 Predicted Fit: **{id2label[pred_label]}** with {confidence:.2%} confidence.")

    print("\n📊 Probability Scores:")
    for i, prob in enumerate(probs[0]):
        print(f"  - {id2label[i]}: {prob.item():.2%}")

    print(f"\n⭐ Match Score (Good Fit Probability): {good_fit_prob:.2%}")

    print("="*80)

    return {
        "pred_label": pred_label,
        "confidence": confidence,
        "good_fit_prob": good_fit_prob
    }


# =========================
# Step 6 – Test Samples
# =========================
resume_no_fit = """
Experienced barista with 4 years in food service. Skilled in preparing espresso-based drinks, operating POS systems, and delivering high customer satisfaction in fast-paced cafés. Seeking to advance in hospitality industry.
"""

job_no_fit = """
We are hiring a Senior Machine Learning Engineer to join our FinTech team. Required skills include Python, TensorFlow, cloud deployment (AWS or Azure), and at least 3 years of experience in ML model training and MLOps pipelines.
"""

resume_potential = """
Recent graduate with a degree in Data Science. Completed coursework in machine learning, statistics, and Python. Completed a capstone project building a recommendation system. Eager to apply skills in an internship setting.
"""

job_potential = """
Looking for a junior data analyst to support data processing and visualization efforts. Experience with SQL, data dashboards, and machine learning concepts preferred.
"""

resume_good = """
Data analyst with 3 years of experience analyzing customer behavior using Python, SQL, and Tableau. Delivered weekly insights to marketing team, improving campaign performance by 18%. Experienced with scikit-learn, pandas, and cloud tools.
"""

job_good = """
We are seeking an experienced data analyst to join our customer insights team. Must have strong skills in Python, SQL, and data visualization (Tableau or Power BI). Knowledge of machine learning libraries is a plus.
"""

# Put your samples in a list of tuples
samples = [
    (resume_no_fit, job_no_fit),
    (resume_potential, job_potential),
    (resume_good, job_good)
]

match_scores = []

# Run predictions for each sample, print details, and store match scores
for i, (res, job) in enumerate(samples, 1):
    print(f"\n=== Sample {i} ===")
    result = predict_fit(res, job)
    match_scores.append(result['good_fit_prob'])

# Summary of match scores
print("\nSummary of Match Scores per sample:")
for i, score in enumerate(match_scores, 1):
    print(f"Sample {i} Good Fit Match Score: {score:.2%}")
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.55.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.34.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.6.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.8.3)
# Mounted at /content/drive
#
# === Sample 1 ===
# 📄 Resume:
# Experienced barista with 4 years in food service. Skilled in preparing espresso-based drinks, operating POS systems, and delivering high customer satisfaction in fast-paced cafés. Seeking to advance i...
#
# 📝 Job Description:
# We are hiring a Senior Machine Learning Engineer to join our FinTech team. Required skills include Python, TensorFlow, cloud deployment (AWS or Azure), and at least 3 years of experience in ML model t...
#
# 🔍 Predicted Fit: **Potential Fit** with 62.98% confidence.
#
# 📊 Probability Scores:
#   - No Fit: 36.39%
#   - Potential Fit: 62.98%
#   - Good Fit: 0.62%
#
# ⭐ Match Score (Good Fit Probability): 0.62%
# ================================================================================
#
# === Sample 2 ===
# 📄 Resume:
# Recent graduate with a degree in Data Science. Completed coursework in machine learning, statistics, and Python. Completed a capstone project building a recommendation system. Eager to apply skills in...
#
# 📝 Job Description:
# Looking for a junior data analyst to support data processing and visualization efforts. Experience with SQL, data dashboards, and machine learning concepts preferred....
#
# 🔍 Predicted Fit: **Good Fit** with 49.79% confidence.
#
# 📊 Probability Scores:
#   - No Fit: 25.58%
#   - Potential Fit: 24.63%
#   - Good Fit: 49.79%
#
# ⭐ Match Score (Good Fit Probability): 49.79%
# ================================================================================
#
# === Sample 3 ===
# 📄 Resume:
# Data analyst with 3 years of experience analyzing customer behavior using Python, SQL, and Tableau. Delivered weekly insights to marketing team, improving campaign performance by 18%. Experienced with...
#
# 📝 Job Description:
# We are seeking an experienced data analyst to join our customer insights team. Must have strong skills in Python, SQL, and data visualization (Tableau or Power BI). Knowledge of machine learning libra...
#
# 🔍 Predicted Fit: **Good Fit** with 71.65% confidence.
#
# 📊 Probability Scores:
#   - No Fit: 16.55%
#   - Potential Fit: 11.80%
#   - Good Fit: 71.65%
#
# ⭐ Match Score (Good Fit Probability): 71.65%
# ================================================================================
#
# Summary of Match Scores per sample:
# Sample 1 Good Fit Match Score: 0.62%
# Sample 2 Good Fit Match Score: 49.79%
# Sample 3 Good Fit Match Score: 71.65%
